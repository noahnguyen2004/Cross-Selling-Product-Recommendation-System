# %% [markdown]
# <a href="https://colab.research.google.com/github/noahnguyen2004/Cross-Selling-Product-Recommendation-System/blob/main/next_best_product.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install scikit-plot

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler

from sklearn.metrics import (
    accuracy_score, confusion_matrix, classification_report,
    roc_auc_score, roc_curve, auc,
    ConfusionMatrixDisplay
)

from sklearn.metrics import ConfusionMatrixDisplay, RocCurveDisplay
from scikitplot.metrics import plot_roc_curve

from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

from keras.metrics import AUC

# %% [markdown]
# # Next Best Product: A Cross-Selling Recommendation System

# %% [markdown]
# Have you bought something off Amazon and it recommends you the related items that you may also consider buying? If so, this project dives into exactly how that whole process goes, and by the end of this project, we will have a deep intuition of how other items are recommended based on what we bought!

# %% [markdown]
# ## What is Association-rule learning?

# %% [markdown]
# Association-rule learning is a rule-based segmentation method in machine learning. It is a method that discovers interesting relations between variables in large databases.

# %% [markdown]
# If you aren't familiar with segmentation methods in machine learning, don't worry, because we will explain it in detail below. There are 2 main segmentation methods worth considering, rule-based segmentation and cluster-based segmentation.

# %% [markdown]
# ### Rule-based segmentation

# %% [markdown]
# This segmentation method defines some rules to partition data points into different segments. These rules are primarily based on domain knowledge, logical conditions, or specific thresholds. The segmentation process relies on predefined rules that guide on how data points are assigned to different segments.

# %%
df = pd.read_csv('/content/drive/MyDrive/cross-selling products/Grocery Products Purchase.csv')
df
# Out:
#                 Product 1            Product 2         Product 3  \
# 0            citrus fruit  semi-finished bread         margarine
# 1          tropical fruit               yogurt            coffee
# 2              whole milk                  NaN               NaN
# 3               pip fruit               yogurt      cream cheese
# 4        other vegetables           whole milk    condensed milk
# ...                   ...                  ...               ...
# 9830              sausage              chicken              beef
# 9831    cooking chocolate                  NaN               NaN
# 9832              chicken         citrus fruit  other vegetables
# 9833  semi-finished bread        bottled water              soda
# 9834              chicken       tropical fruit  other vegetables
#
#                      Product 4      Product 5       Product 6  \
# 0                  ready soups            NaN             NaN
# ...
